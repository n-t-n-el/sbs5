# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
import re
import statsmodels.formula.api as smf
from scipy.stats import pearsonr
from scipy.stats import spearmanr
from sklearn.preprocessing import StandardScaler
from scipy import stats

# %%
import session_info
session_info.show()
# Out:
# <details>
# <summary>Click to view session information</summary>
# <pre>
# -----
# matplotlib          3.7.1
# numpy               1.24.4
# pandas              2.0.3
# scipy               1.9.1
# seaborn             0.12.2
# session_info        1.0.0
# sklearn             1.3.0
# statsmodels         0.13.2
# -----
# </pre>
# <details>
# <summary>Click to view modules imported as dependencies</summary>
# <pre>
# PIL                 8.2.0
# appnope             0.1.0
# backcall            0.2.0
# beta_ufunc          NA
# binom_ufunc         NA
# bottleneck          1.3.2
# cffi                1.17.1
# cloudpickle         1.6.0
# colorama            0.4.4
# comm                0.2.0
# cycler              0.10.0
# cython_runtime      NA
# dateutil            2.8.2
# decorator           4.4.2
# hypergeom_ufunc     NA
# importlib_metadata  NA
# importlib_resources NA
# ipykernel           5.3.4
# ipython_genutils    0.2.0
# ipywidgets          8.1.1
# jedi                0.19.2
# joblib              1.3.1
# kiwisolver          1.3.0
# mpl_toolkits        NA
# nbinom_ufunc        NA
# ncf_ufunc           NA
# numexpr             2.7.1
# packaging           25.0
# parso               0.8.4
# patsy               0.5.2
# pexpect             4.8.0
# pickleshare         0.7.5
# prompt_toolkit      3.0.8
# psutil              7.0.0
# ptyprocess          0.6.0
# pyarrow             11.0.0
# pygments            2.19.1
# pyparsing           2.4.7
# pytz                2020.1
# setuptools          69.0.2
# six                 1.15.0
# sphinxcontrib       NA
# storemagic          NA
# threadpoolctl       2.1.0
# tornado             6.4
# traitlets           5.0.5
# typing_extensions   NA
# vscode              NA
# wcwidth             0.2.5
# zmq                 19.0.2
# zope                NA
# </pre>
# </details> <!-- seems like this ends pre, so might as well be explicit -->
# <pre>
# -----
# IPython             7.19.0
# jupyter_client      6.1.7
# jupyter_core        4.6.3
# jupyterlab          2.2.6
# notebook            6.1.4
# -----
# Python 3.8.5 (default, Sep  4 2020, 02:22:02) [Clang 10.0.0 ]
# macOS-10.16-x86_64-i386-64bit
# -----
# Session information updated at 2025-11-18 15:38
# </pre>
# </details>

# %%
wsize = "1Mb"
dat = pd.read_csv(f"../data/features2windows/{wsize}.merged.tab.gz", sep="\t", na_values=".")
#sig = pd.read_csv(f"../data/features2windows/{wsize}.signatures.tab.gz", sep="\t", na_values=".")

dat["id"] = dat.chrom + dat.start.astype("str")
#sig["id"] = sig.chrom + sig.start.astype("str")

#dat = pd.merge(dat, sig, on="id")

# %%
def fit_ols_semipartial_r2(df, y, covars):
    covar_str = " + ".join(covars)
    mod = smf.ols(f"{y} ~ {covar_str}", data=df).fit()
    
    sr2s = {}
    
    for covar in covars:
        if len(covars) > 1:
            reduced_covars = [c for c in covars if c != covar]
            reduced_covar_str = ' + '.join(reduced_covars)
            reduced_mod = smf.ols(f"{y} ~ {reduced_covar_str}", data=df).fit()
            sr2s[covar] = (mod.rsquared - reduced_mod.rsquared)
        else:
            sr2s[covar] = mod.rsquared
    
    total_r2 = mod.rsquared
    
    return sr2s, mod

def fit_exp_decay(x, y0):
    y = np.log(np.array(y0) + 1)
    slope, intercept, _, _, _ = linregress(x, y)
    return intercept, slope

def infer_repair_rate(row: pd.Series, columns: list) -> float:

    times = []
    dmgs = []

    for col in columns:
        match = re.search(r'_(\d+)_', col) # Extracts time from column name
        if match:
            t = int(match.group(1))
            # Handle cases where the same time point has multiple replicates
            times.append(t)
            dmgs.append(row[col])
        else:
            print(f"Warning: Could not parse time from column: {col}")

    if not times or not dmgs or len(times) < 2:
        return np.nan # Not enough data to fit

    # Sort by time to ensure correct fitting
    sorted_indices = np.argsort(times)
    t_data = np.array(times)[sorted_indices]
    y_data = np.array(dmgs)[sorted_indices]

    _,slope = fit_exp_decay(t_data, y_data)

    return slope

# %%
col_remap = {"ESC_Rep1.bed.gz-ESC_1": "rep_timing_1", 
             "ESC_Rep2.bed.gz-ESC_2": "rep_timing_2", 
             "ESC_Rep1.bed.gz-ESC_3": "rep_timing_3", 
             "GSE113957_fpkm_xL_sorted.bed-GSE113957_fpkm_xL_sorted": "total_expression_fibroblasts", 
             "hg19_refGene_transcripts_merged_overlap_count":"gene_perc", 
             "20141020_strict_mask_whole_genome_overlap_count": "complex_regions_perc", 
             "Jiang2023-bpde_Cell_0_25uM_1": "Jiang2023-bpde_Cell_0.25uM_1", 
             "Jiang2023-bpde_Cell_0_25uM_2": "Jiang2023-bpde_Cell_0.25uM_2", 
             "Jiang2023-bpde_Cell_0_5uM_1": "Jiang2023-bpde_Cell_0.5uM_1", 
             "Jiang2023-bpde_Cell_0_5uM_2": "Jiang2023-bpde_Cell_0.5uM_2"}
dat = dat.rename(columns = col_remap)
dat = dat.rename(columns = {c:c.replace("Yoshida2020-", "") 
                            for c in dat.columns if "Yoshida2020" in c})

# Get rid of windows with (mostly) just gaps & short lenghts
dat = dat[(dat.N_content<100e3) & 
          (dat.total_len>500e3)].reset_index(drop=True)

# Ratio of SBS5
dat["sbs5_ratio"] = dat["ever_smoker_sbs5"] / dat["non_smoker_sbs5"]
dat["sbs5_sbs4_ratio"] = np.log2(dat.ever_smoker_sbs5 / dat.ever_smoker_sbs4)

# Norm by median
for smoke in ["ever_smoker", "non_smoker", "smoker"]:
    for sbs in ["sbs5", "sbs4", "sbs40"]:
        dat[f"{smoke}_{sbs}_norm"] = dat[f"{smoke}_{sbs}"] / dat[f"{smoke}_{sbs}"].median()

# Expression per base-pair
denominator = dat.gene_perc * dat.total_len
dat["expression_rate"] = np.where(
    denominator != 0,
    dat.total_expression_fibroblasts / denominator,
    np.nan  # or 0, depending on what makes sense for your case
)

# NER early readouts
hu_early_ner = ["Hu2017-cpd_0_1", "Hu2017-cpd_0_2", "Hu2017-cpd_60_1", "Hu2017-cpd_60_2"]
dat["cpd_ner_hu"] = dat[hu_early_ner].sum(axis=1)
li_early_ner = ["Li2017-cpd_240_1", "Li2017-cpd_240_2"]
dat["cpd_ner_li"] = dat[li_early_ner].sum(axis=1)
li_bpde_ner = ["Li2017-bpde_60_1", "Li2017-bpde_60_2"]
dat["bpde_ner_li"] = dat[li_bpde_ner].sum(axis=1)

# Damage
dat["bpde_naked_2uM"] = dat["Jiang2023-bpde_nDNA_2uM_1"] + dat["Jiang2023-bpde_nDNA_2uM_2"]
dat["bpde_cell_2uM"] = dat["Jiang2023-bpde_Cell_2uM_1"] + dat["Jiang2023-bpde_Cell_2uM_2"]

# Repair
dmg_cols = [
    'Hu2017-cpd_0_1',
    'Hu2017-cpd_0_2',
    'Hu2017-cpd_1440_1',
    'Hu2017-cpd_1440_2',
    'Hu2017-cpd_2160_1',
    'Hu2017-cpd_2160_2',
    'Hu2017-cpd_2880_1',
    'Hu2017-cpd_2880_2',
    'Hu2017-cpd_480_1',
    'Hu2017-cpd_480_2',
    'Hu2017-cpd_60_1',
    'Hu2017-cpd_60_2']

dat["cpd_repair"] = dat.apply(infer_repair_rate, axis=1, columns=dmg_cols) * -1

# %%
pd.read_csv(f"../data/features2windows/{wsize}.merged.csv.gz")
# Out:
#       chrom     start       end  Adar2016-cpd_1440_1  Adar2016-cpd_1440_2  \
# 0      chr1         0   1000000          59664.05200          75120.53865
# 1      chr1   1000000   2000000         140033.79920         201563.86270
# 2      chr1   2000000   3000000         157820.63760         218168.97540
# 3      chr1   3000000   4000000         157797.56070         214094.71560
# 4      chr1   4000000   5000000         129622.61750         158498.25380
# ...     ...       ...       ...                  ...                  ...
# 2892  chr22  47000000  48000000         262051.34430         289950.30270
# 2893  chr22  48000000  49000000         176902.50000         194040.55310
# 2894  chr22  49000000  50000000         181590.90170         207377.27340
# 2895  chr22  50000000  51000000         179176.03380         238737.79630
# 2896  chr22  51000000  51304566          51070.96794          63330.54801
#
#       Adar2016-cpd_240_1  Adar2016-cpd_240_2  Adar2016-cpd_2880_1  \
# 0            70417.36172        124206.59420          73032.01457
# 1           231726.64330        337047.64010         105447.74180
# 2           141474.95470        208151.18970         162539.73840
# 3           116856.96900        187611.31690         161184.36850
# 4            33802.35156         54936.06623         205755.56700
# ...                  ...                 ...                  ...
# 2892        131403.83960        221748.85810         191792.40580
# 2893         43139.25591         68003.44480         262928.83790
# 2894         43233.79332         72267.58886         281231.71140
# 2895        224707.26280        350417.83900         136216.30000
# 2896         47724.16425         75983.97011          39091.58559
#
#       Adar2016-cpd_2880_2  Adar2016-cpd_480_1  ...   AT_perc   GC_perc  \
# 0            106275.43760         87339.04776  ...  0.446801  0.393199
# 1            157589.18600        246783.24310  ...  0.431085  0.568915
# 2            183622.38530        173498.97570  ...  0.396867  0.553133
# 3            173924.96090        161354.99070  ...  0.365866  0.484134
# 4            173766.22680         58645.92782  ...  0.517799  0.482201
# ...                   ...                 ...  ...       ...       ...
# 2892         177063.95860        218738.75880  ...  0.506619  0.493381
# 2893         198893.77990         70347.15342  ...  0.523974  0.476026
# 2894         210728.07090         79076.62073  ...  0.494231  0.505769
# 2895         165742.71950        280089.14880  ...  0.428710  0.521290
# 2896          40364.65879         59918.73843  ...  0.391787  0.411211
#
#       A_perc  C_content  G_content  T_content  N_content  other_content  \
# 0     225913     196592     196607     220888     160000              0
# 1     220706     286534     282381     210379          0              0
# 2     194390     275953     277180     202477      50000              0
# 3     182525     242882     241252     183341     150000              0
# 4     254270     237650     244551     263529          0              0
# ...      ...        ...        ...        ...        ...            ...
# 2892  242706     240845     252536     263913          0              0
# 2893  264039     236788     239238     259935          0              0
# 2894  245113     254051     251718     249118          0              0
# 2895  217067     261115     260175     211643      50000              0
# 2896   56627      60446      64795      62698      60000              0
#
#       total_len  cpd_repair
# 0       1000000    0.000385
# 1       1000000    0.000668
# 2       1000000    0.000536
# 3       1000000    0.000602
# 4       1000000    0.000435
# ...         ...         ...
# 2892    1000000    0.000638
# 2893    1000000    0.000439
# 2894    1000000    0.000433
# 2895    1000000    0.000654
# 2896     304566    0.000656
#
# [2897 rows x 106 columns]

# %%
sns.scatterplot(data=dat, x="cpd_repair", y="smoker_sbs4")
# Out:
# <Axes: xlabel='cpd_repair', ylabel='smoker_sbs4'>

# %%
r2, mod = fit_ols_semipartial_r2(dat, "smoker_sbs5", ["cpd_repair", "rep_timing_2", "gene_perc"])
print(r2)
# Out:
# {'cpd_repair': 0.07453999970908354, 'rep_timing_2': 0.07111566105865008, 'gene_perc': 0.03433666348168918}

# %%
dat["repair_perc_interval"] = pd.qcut(dat.cpd_repair, q=100)
dat["repair_perc"] = dat.repair_perc_interval.apply(lambda x: x.mid).astype(float)

dat["rep_timing_interval"] = pd.qcut(dat.cpd_repair, q=100)
dat["rep_timing_perc"] = dat.repair_perc_interval.apply(lambda x: x.mid).astype(float)

icols = ["smoker_sbs5", "smoker_sbs4", "rep_timing_1", "gene_perc"]
res = dat.groupby("repair_perc")[icols].sum().reset_index()
icols = ["smoker_sbs5", "smoker_sbs4", "cpd_repair", "gene_perc"]
res2 = dat.groupby("rep_timing_perc")[icols].sum().reset_index()

# %%
sns.scatterplot(data=res, x="repair_perc", y="smoker_sbs5")
# Out:
# <Axes: xlabel='repair_perc', ylabel='smoker_sbs5'>

# %%
sns.scatterplot(data=res, x="rep_timing_1", y="smoker_sbs5")
# Out:
# <Axes: xlabel='rep_timing_1', ylabel='smoker_sbs5'>

# %%
fit_ols_semipartial_r2(res, "smoker_sbs5", ["repair_perc", "rep_timing_1", "gene_perc"])
# Out:
# ({'repair_perc': 0.11457157049051037,
#   'rep_timing_1': 0.057007831233042094,
#   'gene_perc': 0.005779152887603001},
#  <statsmodels.regression.linear_model.RegressionResultsWrapper at 0x7f9ed8f24610>)

# %%
model = smf.ols("smoker_sbs5 ~ repair_perc + rep_timing_1 + gene_perc", data=dat).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            smoker_sbs5   R-squared:                       0.538
# Model:                            OLS   Adj. R-squared:                  0.535
# Method:                 Least Squares   F-statistic:                     186.0
# Date:                Wed, 29 Oct 2025   Prob (F-statistic):           5.94e-80
# Time:                        12:53:48   Log-Likelihood:                -3462.9
# No. Observations:                 483   AIC:                             6934.
# Df Residuals:                     479   BIC:                             6951.
# Df Model:                           3
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     2514.4875    134.610     18.680      0.000    2249.988    2778.987
# repair_perc  -1.799e+06    2.1e+05     -8.570      0.000   -2.21e+06   -1.39e+06
# rep_timing_1  -304.5679     35.010     -8.699      0.000    -373.360    -235.776
# gene_perc     -731.6784    130.238     -5.618      0.000    -987.586    -475.770
# ==============================================================================
# Omnibus:                       77.147   Durbin-Watson:                   1.449
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              192.289
# Skew:                           0.808   Prob(JB):                     1.76e-42
# Kurtosis:                       5.635   Cond. No.                     1.63e+04
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.63e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
# !ls ../data/Yoshida2020/
# Out:
# 41586_2020_1961_MOESM2_ESM.xlsx
# Bronchial epithelium indels.xlsx
# Bronchial epithelium subs.xlsx
# Bronchial epithelium svs.xlsx
# CT_profile.pdf
# Fig2a.xlsx
# Lung_organoids_telomeres_with_contamination_20190408.txt
# MuSiCal
# SigProfilerAssignment
# TLS_error_spectrum.pdf
# TLS_spectrum.ipynb
# Yoshida2020_clusters.csv.gz
# Yoshida2020-annotated.csv.gz
# Yoshida2020-clustered.csv.gz
# Yoshida2020-signet-branches.tab
# Yoshida2020-signet-never-smokers-along-repair.tab
# Yoshida2020-signet-neversmokers-along.tab
# Yoshida2020-signet-smokers-along-repair.tab
# Yoshida2020-signet-smokers-along.tab
# Yoshida2020-signet.tab
# Yoshida2020.csv.gz
# Yoshida2020.ipynb
# Yoshida2020.pre.csv.gz
# Yoshida2020.tab.gz
